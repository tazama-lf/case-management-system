# %%
# Install missing packages
# %pip install matplotlib

# Import necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display, HTML
import requests
import json

# Get transaction ID from URL parameters (if available)
from urllib.parse import parse_qs
import ipywidgets as widgets

# Placeholder for transaction data
transaction_id = 'f8b8...'  # This would come from URL param

print(f"Visualizing transaction: {transaction_id}")

# %%
# Sample transaction data (in real implementation, fetch from API)
sample_data = {
    'debtor': 'John Doe',
    'creditor': 'Jane Smith',
    'amount': 1250.50,
    'currency': 'USD',
    'charges': [100, 50, 200],
    'timestamp': '2025-01-14T05:52:31.244Z'
}

# Display transaction summary
display(HTML(f"""
<h3>Transaction Summary</h3>
<p><strong>Debtor:</strong> {sample_data['debtor']}</p>
<p><strong>Creditor:</strong> {sample_data['creditor']}</p>
<p><strong>Amount:</strong> {sample_data['currency']} {sample_data['amount']}</p>
<p><strong>Timestamp:</strong> {sample_data['timestamp']}</p>
"""))

# %%
# Visualize charges
plt.figure(figsize=(8, 5))
plt.bar(['Charge 1', 'Charge 2', 'Charge 3'], sample_data['charges'])
plt.title('Transaction Charges Breakdown')
plt.ylabel('Amount (USD)')
plt.show()
